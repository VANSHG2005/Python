# %% [markdown]
# <a href="https://colab.research.google.com/github/VANSHG2005/Python/blob/main/Airbnb_NYC_2019_Styled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Airbnb NYC 2019

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **BY-**
#
#  **VANSH GARG -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# 📄**Project Summary: Airbnb NYC 2019 Data Analysis**
#
# This project focuses on exploring and analyzing the Airbnb NYC 2019 dataset to uncover patterns in listing behavior, pricing strategies, guest engagement, and host activity across different boroughs of New York City. The aim is to gain actionable insights that can guide hosts and the Airbnb platform in improving listing performance, pricing decisions, and customer satisfaction.
#
# 📊 **Exploratory Data Analysis**
#
# The dataset includes variables such as neighbourhood_group, neighbourhood, room_type, price, minimum_nights, availability_365, number_of_reviews, reviews_per_month, and others. An initial analysis revealed that there are 5 neighbourhood groups—Manhattan, Brooklyn, Queens, Bronx, and Staten Island—and over 200 unique neighbourhoods. A grouped count showed how each borough contains a varying number of neighbourhoods, with Brooklyn having the most.
#
# A pie chart was used to illustrate the distribution of neighbourhoods across boroughs. This helped visualize how concentrated the Airbnb market is, with Brooklyn and Manhattan making up the majority of listings. The pie chart was chosen for its ability to effectively show proportional representation, offering quick comparative insight into borough dominance.
#
# 🏠 **Room Types and Distribution**
#
# A grouped bar chart demonstrated the number of room types across neighbourhood groups, showing that “Entire home/apt” is the most popular listing type in Manhattan, while “Private room” dominates in Brooklyn and Queens. This visualization made it clear how different boroughs cater to different types of guests—luxury travelers vs. budget-conscious ones.
#
# We also calculated and visualized the average price per room type, revealing that “Entire home/apt” has the highest average price, followed by private and shared rooms. This supports common market expectations and offers guidance to hosts in positioning their listings strategically.
#
# 💰 **Price & Engagement Relationships**
#
# The correlation heatmap helped assess relationships between numerical features. Interestingly, there was no strong linear correlation between price and other factors like minimum_nights, reviews, or availability_365, though some mild relationships (e.g., between reviews and availability) were noted.
#
# A scatter plot was used to examine the relationship between minimum nights and price. The plot showed a wide spread, with most listings having a minimum night stay between 1–7, but with huge price variation. This suggests that price is more influenced by location and room type than by minimum stay requirements.
#
# Another scatter plot analyzed reviews per month vs. price, which also revealed no strong correlation. This indicates that higher prices do not necessarily guarantee more guest engagement, and review frequency is likely influenced by listing quality, location, and host responsiveness.
#
# 🏘️ **Location-Based Insights**
#
# A bar chart visualized the average minimum nights by neighbourhood group, showing that Manhattan had the highest average, which may reflect a tendency toward longer-term rentals or policy differences in densely regulated areas.
#
# We also explored median price by neighbourhood group and room type. Manhattan consistently had the highest median prices for all room types, especially for entire apartments. This reinforces its premium positioning in the Airbnb market.
#
# 📌 **Additional Insights**
#
# Several unique visualizations added further value:
#
# * A pair plot to explore distributions and relationships across numerical features.
# * A scatter geo-plot (optional) to map listing density by location.
# * Potential new metrics like engagement rate (reviews per month divided by availability) were considered to deepen the analysis.
#
# 📈 **Conclusion**
#
# The analysis of the Airbnb NYC 2019 dataset revealed rich insights into how price, room type, location, and engagement interact in the short-term rental market. Key findings include the dominance of entire homes in Manhattan, price variability regardless of stay length, and the limited predictive value of price on guest activity. These insights can help hosts refine their offerings and help Airbnb identify trends to improve its platform strategy.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/VANSHG2005/Python/blob/main/Airbnb_NYC_2019_Styled.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Airbnb has become a major player in the short-term rental market, particularly in large cities like New York City. With thousands of listings varying by location, room type, price, availability, and host activity, there is a need to understand the factors that influence pricing, customer engagement, and listing distribution. This analysis aims to explore the Airbnb NYC 2019 dataset to uncover insights that can help both the platform and hosts improve their offerings, pricing strategies, and customer experiences.
#
# The goal of this project is to:
#
# * Analyze the spatial distribution of listings across different boroughs and neighborhoods in NYC.
# * Understand the pricing dynamics across room types and locations.
# Explore the relationship between availability, reviews, and price.
# * Identify patterns in host behavior and guest engagement.
# * Detect outliers or anomalies that may affect business performance.
# *Derive actionable insights that can support data-driven decision-making for hosts and Airbnb as a business.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The objective of this analysis is to extract meaningful insights from the Airbnb NYC 2019 dataset to optimize listing performance, enhance user experience, and support business growth for hosts and the platform. By identifying trends in pricing, availability, room types, and guest engagement across different boroughs of New York City, the goal is to provide data-driven recommendations that:
#
# * Help hosts maximize revenue by optimizing their pricing and availability strategies.
# * Identify high-performing areas and room types to guide investment or expansion decisions.
# * Improve platform transparency and trust by understanding user behavior through review patterns.
# * Support Airbnb’s internal teams (e.g., marketing, product, host management) with insights that align listings better with customer expectations.
# * Detect outliers or potentially fraudulent listings that may violate platform policies.
#
# Ultimately, this project seeks to empower stakeholders with insights that can drive both operational efficiency and strategic planning in a competitive short-term rental market.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import math
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

from matplotlib import rcParams

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DataSet/Copy of Airbnb NYC 2019.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
dataset.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
dataset.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(dataset[dataset.duplicated()])
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(dataset.isnull().sum())
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
plt.figure()
# Visualizing the missing values
# Checking Null Value by plotting Heatmap
sns.heatmap(dataset.isnull(), cbar=False)
plt.show()
# Out:
# <Axes: >

# %% [markdown]
# ###What did you know about your dataset? ###

# %% [markdown]
# The dataset given is from the Airbnb listings in New York City for the year 2019. It provides detailed information about hosts, listings, pricing, and geographical distribution across different boroughs of NYC.
#
# This dataset can be used to perform various types of analysis such as neighborhood-level price trends, host activity patterns, listing availability, and customer engagement through reviews.
#
# The above dataset contains 48,895 rows and 16 columns. Each row represents an individual Airbnb listing. The dataset includes some missing values in columns like name, last_review, and reviews_per_month. There are no duplicate listing IDs.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
dataset.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
dataset.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# * **ID**: Unique identifier for each listing
#
# * **Name**: Title of the listing
#
# * **Host Id**: Unique identifier for each host
#
# * **Host Name**: Name of the host
#
# * **Neighbourhood Group**: Broad geographical region (e.g., Brooklyn, Manhattan)
#
# * **Neighbourhood**: Specific neighborhood location of the listing
#
# * **Latitude**: Latitude coordinate of the listing
#
# * **Longitude**: Longitude coordinate of the listing
#
# * **Room Type**: Type of room offered (Entire home/apt, Private room, Shared room)
#
# * **Price**: Price per night (in USD)
#
# * **Minimum Nights**: Minimum number of nights required to book
#
# * **Number of Reviews**: Total number of reviews received by the listing
#
# * **Last Review**: Date of the most recent review
#
# * **Reviews Per Month**: Average number of reviews per month
#
# * **Calculated Host Listings Count**: Number of listings a host has
#
# * **Availability**: Number of days the listing is available in a year

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in dataset.columns.tolist():
  print("No. of unique values in ",i,"is",dataset[i].nunique(),".")
# Out:
# No. of unique values in  id is 48895 .
# No. of unique values in  name is 47905 .
# No. of unique values in  host_id is 37457 .
# No. of unique values in  host_name is 11452 .
# No. of unique values in  neighbourhood_group is 5 .
# No. of unique values in  neighbourhood is 221 .
# No. of unique values in  latitude is 19048 .
# No. of unique values in  longitude is 14718 .
# No. of unique values in  room_type is 3 .
# No. of unique values in  price is 674 .
# No. of unique values in  minimum_nights is 109 .
# No. of unique values in  number_of_reviews is 394 .
# No. of unique values in  last_review is 1764 .
# No. of unique values in  reviews_per_month is 937 .
# No. of unique values in  calculated_host_listings_count is 47 .
# No. of unique values in  availability_365 is 366 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %%
# Handle missing values
dataset['name'].fillna("Unknown", inplace=True)
dataset['host_name'].fillna("Unknown", inplace=True)
dataset['reviews_per_month'].fillna(0, inplace=True)
dataset['last_review'].fillna(method='bfill', inplace=True)

# %%
# Getting Unique Neighbourhood Group
print(dataset['neighbourhood_group'].unique())
print(" ")
# Getting Unique Neighbourhood Group Count
print("Unique Neighbourhood Count is ",dataset['neighbourhood_group'].nunique(),".")
# Out:
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
#
# Unique Neighbourhood Count is  5 .

# %%
# Getting Unique Neighbourhood
print(dataset['neighbourhood'].unique())
print(" ")
# Getting Unique Neighbourhood Group Count
print("Unique Neighbourhood Count is ",dataset['neighbourhood'].nunique(),".")
# Out:
# ['Kensington' 'Midtown' 'Harlem' 'Clinton Hill' 'East Harlem'
#  'Murray Hill' 'Bedford-Stuyvesant' "Hell's Kitchen" 'Upper West Side'
#  'Chinatown' 'South Slope' 'West Village' 'Williamsburg' 'Fort Greene'
#  'Chelsea' 'Crown Heights' 'Park Slope' 'Windsor Terrace' 'Inwood'
#  'East Village' 'Greenpoint' 'Bushwick' 'Flatbush' 'Lower East Side'
#  'Prospect-Lefferts Gardens' 'Long Island City' 'Kips Bay' 'SoHo'
#  'Upper East Side' 'Prospect Heights' 'Washington Heights' 'Woodside'
#  'Brooklyn Heights' 'Carroll Gardens' 'Gowanus' 'Flatlands' 'Cobble Hill'
#  'Flushing' 'Boerum Hill' 'Sunnyside' 'DUMBO' 'St. George' 'Highbridge'
#  'Financial District' 'Ridgewood' 'Morningside Heights' 'Jamaica'
#  'Middle Village' 'NoHo' 'Ditmars Steinway' 'Flatiron District'
#  'Roosevelt Island' 'Greenwich Village' 'Little Italy' 'East Flatbush'
#  'Tompkinsville' 'Astoria' 'Clason Point' 'Eastchester' 'Kingsbridge'
#  'Two Bridges' 'Queens Village' 'Rockaway Beach' 'Forest Hills' 'Nolita'
# ...

# %%
# Grouping by 'neighbourhood_group' and counting unique 'neighbourhood' values
neighbourhoods_per_group = dataset.groupby('neighbourhood_group')['neighbourhood'].nunique()

print(neighbourhoods_per_group)
# Out:
# neighbourhood_group
# Bronx            48
# Brooklyn         47
# Manhattan        32
# Queens           51
# Staten Island    43
# Name: neighbourhood, dtype: int64

# %%
# Grouping by 'neighbourhood' and counting unique 'Air Bnb' values
neighbourhoods = dataset.groupby('neighbourhood')['name'].nunique()

print(neighbourhoods)
# Out:
# neighbourhood
# Allerton            42
# Arden Heights        4
# Arrochar            21
# Arverne             75
# Astoria            896
#                   ...
# Windsor Terrace    157
# Woodhaven           87
# Woodlawn            11
# Woodrow              1
# Woodside           234
# Name: name, Length: 221, dtype: int64

# %%
# Count of each room_type within each neighbourhood_group
room_types_by_group = dataset.groupby('neighbourhood_group')['room_type'].value_counts().unstack()
print('Each Room Type Within Each Neighbourhood Group')
print(room_types_by_group)
# Out:
# Each Room Type Within Each Neighbourhood Group
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                            379           652           60
# Brooklyn                        9559         10132          413
# Manhattan                      13199          7982          480
# Queens                          2096          3372          198
# Staten Island                    176           188            9

# %%
# Calculate the average price for each room_type
average_price_by_room_type = dataset.groupby(['room_type'])['price'].mean().reset_index()
average_price_by_room_type.columns = ['room_type', 'average_price']
print("Average Price by Room Type:")
print(average_price_by_room_type.to_markdown(index=False, numalign="left", stralign="left"))
# Out:
# Average Price by Room Type:
# | room_type       | average_price   |
# |:----------------|:----------------|
# | Entire home/apt | 211.794         |
# | Private room    | 89.781          |
# | Shared room     | 70.1276         |

# %%
#Total Number of Listings per Neighbourhood Group

listings_by_group = dataset['neighbourhood_group'].value_counts()
print('Total Number of Listing per Neighbourhood Group is: ')
print(listings_by_group)
# Out:
# Total Number of Listing per Neighbourhood Group is:
# neighbourhood_group
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: count, dtype: int64

# %%
#Total Number of Listings per Host

listings_by_host = dataset['host_name'].value_counts()
print('Total Number of Listing per Host is: ')
print(listings_by_host)
# Out:
# Total Number of Listing per Host is:
# host_name
# Michael          417
# David            403
# Sonder (NYC)     327
# John             294
# Alex             279
#                 ...
# Pujan              1
# Raheem             1
# Rusaa              1
# Erin At Bedly      1
# Brad & Rachel      1
# Name: count, Length: 11452, dtype: int64

# %%
#Top 10 Neighbourhoods by Number of Listings

top_neighbourhoods = dataset['neighbourhood'].value_counts().head(10)
print('Top 10 Neighbourhoods By Number of Listing: ')
print(top_neighbourhoods)
# Out:
# Top 10 Neighbourhoods By Number of Listing:
# neighbourhood
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
# Hell's Kitchen        1958
# East Village          1853
# Upper East Side       1798
# Crown Heights         1564
# Midtown               1545
# Name: count, dtype: int64

# %%
#Price Distribution

price_dist = dataset[dataset['price'] < 500]['price']

print('Price Distribution')
print(price_dist)
# Out:
# Price Distribution
# 0        149
# 1        225
# 2        150
# 3         89
# 4         80
#         ...
# 48890     70
# 48891     40
# 48892    115
# 48893     55
# 48894     90
# Name: price, Length: 47660, dtype: int64

# %%
#Availability by Room Type

availability_by_room = dataset.groupby('room_type')['availability_365'].mean()
print('Availability By Room Type')
print(availability_by_room)
# Out:
# Availability By Room Type
# room_type
# Entire home/apt    111.920304
# Private room       111.203933
# Shared room        162.000862
# Name: availability_365, dtype: float64

# %%
#Number of Reviews by Neighbourhood Group

reviews_by_group = dataset.groupby('neighbourhood_group')['number_of_reviews'].sum()
print('Number of Reviews by Neighbourhood Group')
print(reviews_by_group)
# Out:
# Number of Reviews by Neighbourhood Group
# neighbourhood_group
# Bronx             28371
# Brooklyn         486574
# Manhattan        454569
# Queens           156950
# Staten Island     11541
# Name: number_of_reviews, dtype: int64

# %%
#Number of Reviews by Neighbourhood

reviews_by_neighbourhood = dataset.groupby('neighbourhood')['number_of_reviews'].sum()
print('Number of Reviews by Neighbourhood ')
print(reviews_by_neighbourhood)
# Out:
# Number of Reviews by Neighbourhood
# neighbourhood
# Allerton            1803
# Arden Heights         31
# Arrochar             307
# Arverne             2253
# Astoria            19310
#                    ...
# Windsor Terrace     4324
# Woodhaven           2792
# Woodlawn             484
# Woodrow                0
# Woodside            5035
# Name: number_of_reviews, Length: 221, dtype: int64

# %%
#Average Price per Neighbourhood Group

avg_price_by_group = dataset.groupby('neighbourhood_group')['price'].mean()
print('Average Price per Neighbourhood Group')
print(avg_price_by_group)
# Out:
# Average Price per Neighbourhood Group
# neighbourhood_group
# Bronx             87.496792
# Brooklyn         124.383207
# Manhattan        196.875814
# Queens            99.517649
# Staten Island    114.812332
# Name: price, dtype: float64

# %%
#Reviews per Month by Room Type

reviews_monthly = dataset.groupby('room_type')['reviews_per_month'].mean()
print('Reviews per Month by Room Type')
print(reviews_monthly)
# Out:
# Reviews per Month by Room Type
# room_type
# Entire home/apt    1.306578
# Private room       1.445209
# Shared room        1.471726
# Name: reviews_per_month, dtype: float64

# %%
#Average Minimum Nights by Neighbourhood Group

avg_min_nights = dataset.groupby('neighbourhood_group')['minimum_nights'].mean().sort_values(ascending=False)
print('Average Minimum Nights by Neighbourhood Group')
print(avg_min_nights)
# Out:
# Average Minimum Nights by Neighbourhood Group
# neighbourhood_group
# Manhattan        8.579151
# Brooklyn         6.056556
# Queens           5.181433
# Staten Island    4.831099
# Bronx            4.560953
# Name: minimum_nights, dtype: float64

# %%
#Reviews Per Month vs. Price

filter_data = dataset[(dataset['price'] < 1000) & (dataset['reviews_per_month'].notnull())]

# %%
#Median Price by Neighbourhood Group and Room Type

median_price = dataset.groupby(['neighbourhood_group', 'room_type'])['price'].median().reset_index()
print('Median Price by Neighbourhood Group and Room Type')
print(median_price)
# Out:
# Median Price by Neighbourhood Group and Room Type
#    neighbourhood_group        room_type  price
# 0                Bronx  Entire home/apt  100.0
# 1                Bronx     Private room   53.5
# 2                Bronx      Shared room   40.0
# 3             Brooklyn  Entire home/apt  145.0
# 4             Brooklyn     Private room   65.0
# 5             Brooklyn      Shared room   36.0
# 6            Manhattan  Entire home/apt  191.0
# 7            Manhattan     Private room   90.0
# 8            Manhattan      Shared room   69.0
# 9               Queens  Entire home/apt  120.0
# 10              Queens     Private room   60.0
# 11              Queens      Shared room   37.0
# 12       Staten Island  Entire home/apt  100.0
# 13       Staten Island     Private room   50.0
# 14       Staten Island      Shared room   30.0

# %%
#Relationship between Minimum Nights and Price

filtered_data = dataset[(dataset['price'] < 1000) & (dataset['minimum_nights'] < 30)]

# %%
#Correlation Heatmap

# Select relevant numerical columns
numerical_cols = dataset[['price', 'minimum_nights', 'number_of_reviews',
                          'reviews_per_month', 'calculated_host_listings_count', 'availability_365']]

# Optional: remove rows with missing values
numerical_cols = numerical_cols.dropna()

# Compute correlation matrix
correlation_matrix = numerical_cols.corr()

# %%
#Pair Plot

# Filter for better visualization
filtered_data2 = dataset[(dataset['price'] < 500) &
                        (dataset['minimum_nights'] < 30) &
                        (dataset['reviews_per_month'].notnull())]

# Select relevant numerical columns
pairplot_data = filtered_data2[['price', 'minimum_nights', 'number_of_reviews',
                               'reviews_per_month', 'availability_365']]

# %%
#Map Visualization with Plotly

sample_df2 = dataset[dataset['price'] < 500].sample(1000, random_state=1)

# %%
#Box Plot of Price by Room Type

filtered_data3 = dataset[dataset['price'] < 500]
filtered_data4 = dataset[dataset['minimum_nights'] < 30]

# %%
#Average Price by Number of Reviews (used as a proxy for popularity)

# Group by number_of_reviews and calculate average price
avg_price_by_reviews = dataset.groupby('number_of_reviews')['price'].mean().reset_index()

# Optional: filter to avoid noisy outliers
avg_price_by_reviews = avg_price_by_reviews[avg_price_by_reviews['number_of_reviews'] <= 100]

print('Average Price By Number of Reviews')
print(avg_price_by_reviews)
# Out:
# Average Price By Number of Reviews
#      number_of_reviews       price
# 0                    0  192.919021
# 1                    1  149.422387
# 2                    2  148.238961
# 3                    3  144.200000
# 4                    4  144.995988
# ..                 ...         ...
# 96                  96  128.952381
# 97                  97  125.220000
# 98                  98   93.975610
# 99                  99  126.583333
# 100                100  113.877551
#
# [101 rows x 2 columns]

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 🔧 Data Manipulations Performed:
#
# 1. Initial Exploration
#
# * Displayed head of the dataset
# * Checked column types and null values
# * Removed outliers for better clarity in charts (e.g., price > 500 or minimum_nights > 30)
#
# 2. Data Cleaning & Filtering
#
# * Filtered out extreme values (for scatter and box plots)
# * Grouped data by:
#   * neighbourhood_group
#   * room_type
#   * number_of_reviews
#   * minimum_nights
#
# * Calculated:
#   * Mean, median, and count for price, reviews, availability
#
# 3. Grouping and Aggregation
#
# * Grouped data to find:
#   * Unique neighbourhoods in each borough
#   * Room type counts per neighbourhood group
#   * Average/median price per room type and borough
#   * Correlation matrix for numerical columns
#
# 4. Data Visualization Techniques Used
#
# * Pie Charts
# * Bar Graphs
# * Box Plots
# * Scatter Plots
# * Line Graphs
# * Correlation Heatmap
# * Pair Plot
# * Geo scatter plots (latitude vs longitude)
#
#
#
# ---
#
#
#
# **💡 Key Insights Discovered:**
#
# 1. Neighbourhood Group Insights
#
# * Brooklyn has the highest number of listings, followed by Manhattan
# * Manhattan has the highest average price among all boroughs
#
# 2. Room Type Distribution
#
# * Entire home/apt is the most expensive room type
# * Private rooms dominate in Queens, Bronx, and Staten Island
# * Shared rooms are rare and cheapest
#
# 3. Price Insights
#
# * Listings in Manhattan with entire homes/apts have the highest median prices
# * Box plots showed wide price variance in Manhattan and Brooklyn
#
# 4. Minimum Nights
#
# * Most listings have a minimum night requirement of 1 to 7 nights
# * Manhattan has the highest average minimum nights, suggesting more long-term stays
#
# 5. Reviews vs Price
#
# * Scatter plot showed no strong correlation between number of reviews and listing price
# * High review listings are often low to mid-priced
#
# 6. Reviews per Month vs Price
#
# * No clear linear trend — high reviews can happen at any price range
#
# 7. Geographic Listing Distribution
#
# * Geo scatter plot (latitude vs longitude) showed dense clusters in Manhattan and Brooklyn
# * Color-coded by neighbourhood_group for better understanding
#
# 8. Correlation Matrix
#
# * Found weak correlations overall — slight correlation between availability and reviews
#
# 9. Pair Plot
#
# * Helped visualize the relationships among numeric columns like price, number of reviews, minimum nights, availability
#
# 10. Line Plot (Simulated Trend)
#
# * Plotted average price vs number of reviews (proxy for listing popularity)

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Plotting Distribution of Unique Neighbourhoods in Different Neighbourhood Groups

colors = sns.color_palette("Set2", len(neighbourhoods_per_group))

plt.figure(figsize=(15, 8))
neighbourhoods_per_group.plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=90,
    shadow=True,
    colors=colors  # Apply the consistent color scheme
)
plt.title("Distribution of Unique Neighbourhoods by Neighbourhood Group")
plt.ylabel("")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart was chosen to visually represent the proportional distribution of unique neighbourhoods across different neighbourhood groups in NYC. It is effective for:
#
# * Highlighting the share each group contributes to the total
#
# * Quickly identifying which neighbourhood group has the widest geographical diversity in terms of listings
#
# However, it was primarily used for visual appeal and proportional clarity, not for exact comparisons.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the pie chart, we can derive the following insights:
#
# * Some neighbourhood groups (e.g., Brooklyn and Manhattan) have a larger variety of neighbourhoods, suggesting broader listing diversity and potentially greater business reach.
#
# * Groups like Staten Island or Bronx may have fewer neighbourhoods listed, indicating lower Airbnb penetration or less market interest.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights are valuable for business strategy:
#
# * Targeted Expansion: Identifying boroughs with fewer neighbourhoods allows Airbnb to plan targeted marketing or outreach to grow supply in those areas.
#
# * Resource Allocation: More active boroughs with many neighbourhoods might benefit from optimized pricing tools, support services, or experience-based upselling.
#
# There is one potential negative insight is:
#
# Underrepresentation in certain areas (e.g., Staten Island or Bronx) could indicate regulatory issues, lack of demand, or poor infrastructure for hosting. If not addressed, this may lead to:
#
# * Missed revenue opportunities
# * Unbalanced platform presence, reducing trust among guests expecting city-wide options
#
# Failing to understand or resolve why certain boroughs have lower diversity could hinder growth and reinforce market imbalance, especially if competitors tap into these ignored zones.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
#Counting Room Types by Neighbourhood Group

colors = sns.color_palette("Set3")

plt.figure(figsize=(19, 8))
room_types_by_group.plot(
    kind='bar',
    edgecolor='black',
    color=colors
)

plt.title("Room Types by Neighbourhood Group", fontsize=16, fontweight='bold')
plt.xlabel("Neighbourhood Group", fontsize=12)
plt.ylabel("Number of Listings", fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)
plt.legend(title="Room Type", fontsize=10, title_fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  It allows us to:
#
# * Compare multiple categories (room types) across different neighbourhood groups
# * See exact differences in listing counts
# * Spot trends (e.g., which room types are dominant in which boroughs)
#
# The pie chart is less suitable as it only shows one group at a time and cannot show cross-group comparisons effectively.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Private rooms and entire homes/apartments** dominate most neighbourhood groups.
#
# * **Manhattan** has a very high number of entire home/apt listings, which aligns with higher tourism and business travel.
#
# * **Shared rooms** are the least common in all areas, suggesting low demand or host preference against offering them.
#
# * **Brooklyn** also has a high volume of listings across room types, indicating it’s a strong secondary market to Manhattan.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. These insights help:
#
# * **Tailor marketing efforts**: Promote private rooms in budget-sensitive markets, and entire homes in premium zones like Manhattan.
#
# * **Guide host onboarding**: Inform new hosts what room types are in demand in each borough.
#
# * **Influence pricing models**: Adjust pricing strategies depending on supply concentration by type and region.
#
# There are a few insights that lead to negative growth:
#
# * **Over-concentration of one room type** (e.g., entire homes in Manhattan) could make the platform less appealing to budget travelers.
#
# * **Under-representation of shared rooms** might suggest lack of affordable options, possibly driving budget-conscious users to competitors.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
#Average Price by Room Type

colors = sns.color_palette("Set3", len(average_price_by_room_type))

plt.figure(figsize=(9, 6))
plt.bar(
    average_price_by_room_type['room_type'],
    average_price_by_room_type['average_price'],
    color=colors,
    edgecolor='black'
)

plt.title("Average Price by Room Type", fontsize=16, fontweight='bold')
plt.xlabel("Room Type", fontsize=12)
plt.ylabel("Average Price (USD)", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart was chosen because:
#
# * It clearly displays the numerical difference in average price for each room type.
#
# * Bar charts are ideal when you want to compare individual category values directly.
#
# Pie charts, while useful for showing proportions, are not appropriate for average values as they distort the perception of actual price differences.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Entire home/apt listings have the highest average price, which is expected due to the privacy and full space offered.
#
# * Private rooms are significantly more affordable, making them ideal for budget-conscious travelers.
#
# * Shared rooms have the lowest average price but are rare.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights are useful for:
#
# * **Price optimization**: Airbnb can benchmark listings against the average for each room type to detect over/underpricing.
#
# * **Customer targeting**: Helps align listings with traveler budgets (e.g., private rooms for solo travelers, entire homes for families).
#
# * **Host guidance**: Helps new hosts decide which room type to offer based on potential earning.
#
# There are insights that lead to negative growth:
#
# * The **low availability of shared rooms**, despite their affordability, may result in exclusion of ultra-budget travelers.
#
# * **Over-reliance** on high-priced entire homes might make the platform appear expensive in high-demand locations, pushing users to competitors.
#
# * If **price gaps** widen without additional value offered, customers may **perceive unfair pricing, reducing trust and bookings**.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
#Total Number of Listings per Neighbourhood Group

group_names = neighbourhoods_per_group.index.tolist()
pie_colors = sns.color_palette("Set2", len(group_names))
color_map = dict(zip(group_names, pie_colors))

bar_colors = [color_map[group] for group in listings_by_group.index]

plt.figure(figsize=(12, 6))
listings_by_group.plot(
    kind='bar',
    color=bar_colors,
    edgecolor='black'
)

plt.title("Total Listings by Neighbourhood Group", fontsize=16, fontweight='bold')
plt.xlabel("Neighbourhood Group", fontsize=12)
plt.ylabel("Number of Listings", fontsize=12)
plt.xticks(rotation=0, fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen because it effectively represents categorical data (neighbourhood groups) against a quantitative value (number of listings). It clearly shows the comparison of listing volume across different boroughs in NYC, which would be less precise in a pie chart when there are similar-sized segments.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Manhattan** has the highest number of listings, followed closely by Brooklyn.
#
# * **Queens** holds a moderate number of listings, while Bronx and Staten Island have significantly fewer.
#
# * This indicates that **Airbnb activity** is concentrated in Brooklyn and Manhattan, reflecting tourist interest, better infrastructure, or more host engagement.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights help Airbnb and its hosts to:
#
# * Target marketing efforts and promotional strategies in high-performing areas like Brooklyn and Manhattan.
#
# * Identify under-served areas like Staten Island and the Bronx, where there may be untapped market potential.
#
# * Help new hosts decide where to list properties for maximum visibility and guest interest.
#
# * Assist Airbnb in balancing supply and demand more effectively across NYC.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
#Top 10 Neighbourhoods by Number of Listings

bar_colors = sns.color_palette("Set3", len(top_neighbourhoods))

plt.figure(figsize=(10, 6))
top_neighbourhoods.plot(
    kind='bar',
    color=bar_colors,
    edgecolor='black'
)

plt.title("Top 10 Neighbourhoods by Listings", fontsize=16, fontweight='bold')
plt.xlabel("Neighbourhood", fontsize=12)
plt.ylabel("Number of Listings", fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is the best choice here because it clearly shows ranking and comparison among the top 10 neighbourhoods based on the number of listings. Each bar's height represents the total listings in that area, making it easy to identify which neighbourhoods are most popular.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Neighbourhoods like Williamsburg, Harlem, and Bedford-Stuyvesant have the highest number of listings.
#
# * The top 10 neighbourhoods are primarily from Brooklyn and Manhattan, reinforcing earlier findings that these boroughs are Airbnb hotspots.
#
# * The chart also shows how listing volume drops off gradually after the top few neighbourhoods, showing a concentration of listings in specific areas.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights are useful for:
#
# * Identifying high-demand areas where Airbnb can focus its marketing and support efforts.
#
# * Helping new hosts select locations with proven interest from guests.
#
# * Enabling Airbnb to explore dynamic pricing and resource allocation (like customer service or promotional partnerships) in these top-performing neighbourhoods.
#
# Potential negative implications could arise from:
#
# * Oversaturation in top neighbourhoods like Williamsburg or Harlem — too many listings could lead to price competition, reduced occupancy rates, or strained community relations.
#
# * Regulatory scrutiny — areas with very high listing volumes may attract stricter housing regulations or zoning restrictions, which can impact long-term business sustainability.
#
# * Neglect of low-listing areas — underrepresented neighbourhoods might be overlooked for investment, despite possibly having untapped demand.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

light_color = sns.color_palette("pastel")[2]

plt.figure(figsize=(12, 6))
price_dist.plot(
    kind='hist',
    bins=50,
    color=light_color,
    edgecolor='black'
)

plt.title("Distribution of Listing Prices (Under $500)", fontsize=16, fontweight='bold')
plt.xlabel("Price", fontsize=12)
plt.ylabel("Number of Listings", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A histogram is ideal for showing the distribution of numerical data.
#
# * In this case, it clearly illustrates how listing prices are spread across different price ranges, particularly focusing on listings under $500 to avoid outlier distortion.
#
# * It helps detect price concentration, skewness, and irregularities in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The majority of Airbnb listings are concentrated between $50 and $150.
#
# * There is a sharp drop in the number of listings beyond $200.
#
# * This suggests that most hosts aim to price their listings competitively to attract more guests.
#
# * The data is right-skewed, meaning a few high-price listings exist but are rare.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights allow:
#
# * Hosts to understand what price range is most common and competitively price their listings.
#
# * Airbnb to offer pricing recommendations or set up automated smart pricing tools to help new hosts align with the market.
#
# * Identification of affordable market segments, which can inform targeted marketing campaigns.
#
# Potential negative growth risks include:
#
# * Price saturation – too many listings priced within the same range ($50–$150) can increase competition, lowering visibility and profitability.
#
# * Hosts may engage in a race to the bottom, continuously lowering prices to stay competitive, which could hurt revenue in the long run.
#
# * The histogram also hints that luxury or premium listings are underrepresented, which could mean Airbnb is missing out on higher-paying customers who expect upscale options.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Average Availability by Room Type

plt.figure(figsize=(12, 6))
colors = sns.color_palette("Set3", len(average_price_by_room_type))
availability_by_room.plot(kind='bar', color=colors, edgecolor='black')

plt.title("Average Availability (Days) by Room Type", fontsize=16, fontweight='bold')
plt.xlabel("Room Type", fontsize=12)
plt.ylabel("Average Days Available per Year", fontsize=12)
plt.xticks(rotation=0, fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A bar chart was selected because it effectively visualizes comparisons between different room types and their corresponding average availability.
#
# * It gives a clear picture of how many days per year each room type is available, which is crucial for understanding supply dynamics.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Shared rooms have the highest availability, followed by entire home/apt.
#
# * Private show lower availability, possibly due to owner usage or strategic renting.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes. Hosts can adjust availability for better occupancy.
#
# * Airbnb can encourage optimized listing strategies based on room type trends.
#
# Insights that lead to negative growth are:
#
# * Underused high-demand listings (like entire homes) may lead to lost revenue.
#
# * Over-available low-demand rooms may signal inefficient supply.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
#Number of Reviews by Neighbourhood Group

group_names = neighbourhoods_per_group.index.tolist()
pie_colors = sns.color_palette("Set2", len(group_names))
color_map = dict(zip(group_names, pie_colors))

bar_colors = [color_map[group] for group in reviews_by_group.index]

plt.figure(figsize=(8, 6))
reviews_by_group.plot(
    kind='bar',
    color=bar_colors,
    edgecolor='black'
)

plt.title("Total Number of Reviews by Neighbourhood Group", fontsize=16, fontweight='bold')
plt.xlabel("Neighbourhood Group", fontsize=12)
plt.ylabel("Number of Reviews", fontsize=12)
plt.xticks(rotation=0, fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart makes it easy to compare total reviews across neighbourhood groups visually.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Manhattan and Brooklyn receive the most reviews, showing higher guest activity.
#
# * Staten Island and Bronx have the fewest, indicating lower engagement or tourism.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes. Airbnb can focus marketing efforts or host support in areas with fewer reviews to boost visibility.
#
# * High-review areas can be promoted as popular and trusted locations.
#
# Negative insights:
#
# * Low-review areas may reflect low guest interest or host inactivity, which could hurt long-term growth if not addressed.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Total Number of Reviews by Neighbourhood

bar_colors = sns.color_palette("pastel", len(reviews_by_neighbourhood))

plt.figure(figsize=(50, 10))
reviews_by_neighbourhood.plot(
    kind='bar',
    color=bar_colors,
    edgecolor='black'
)

plt.title("Total Number of Reviews by Neighbourhood", fontsize=16, fontweight='bold')
plt.xlabel("Neighbourhood", fontsize=12)
plt.ylabel("Number of Reviews", fontsize=12)
plt.xticks(rotation=90, fontsize=9)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is ideal for showing exact review counts per neighbourhood, especially with many categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * A few neighbourhoods receive a significantly higher number of reviews, indicating strong guest interest.
#
# * Many others have relatively low activity, pointing to underutilized areas.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes. Helps identify high-performing neighbourhoods to expand listings.
#
# * Airbnb can target low-review areas with host support or promotions to increase visibility.
#
# Negative insights:
#
# * Some neighbourhoods with few reviews may reflect poor location appeal or lack of marketing, requiring strategic improvement.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
#Average Price per Neighbourhood Group

group_names = neighbourhoods_per_group.index.tolist()
pie_colors = sns.color_palette("Set2", len(group_names))
color_map = dict(zip(group_names, pie_colors))

bar_colors = [color_map[group] for group in avg_price_by_group.index]

plt.figure(figsize=(12, 6))
avg_price_by_group.plot(
    kind='bar',
    color=bar_colors,
    edgecolor='black'
)

plt.title("Average Price by Neighbourhood Group", fontsize=16, fontweight='bold')
plt.xlabel("Neighbourhood Group", fontsize=12)
plt.ylabel("Average Price", fontsize=12)
plt.xticks(rotation=0, fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart clearly shows how average prices vary across neighbourhood groups, making it easy to compare.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Manhattan has the highest average prices, followed by Brooklyn.
#
# * Bronx and Staten Island offer more budget-friendly listings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Helps Airbnb:
#
# * Guide guests to budget or premium locations based on preference.
#
# * Advise hosts on competitive pricing by location.
#
# Negative insights:
#
# * High prices in some areas (like Manhattan) may discourage budget travelers.
#
# * Low prices elsewhere could suggest lower perceived value or demand.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
#Reviews per Month by Room Type

colors = sns.color_palette("Set3", len(average_price_by_room_type))

plt.figure(figsize=(12, 6))
reviews_monthly.plot(
    kind='bar',
    color = colors,
    edgecolor='black'
)

plt.title("Average Reviews per Month by Room Type", fontsize=16, fontweight='bold')
plt.xlabel("Room Type", fontsize=12)
plt.ylabel("Average Reviews per Month", fontsize=12)
plt.xticks(rotation=0, fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is perfect to compare review frequency across room types, showing performance at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Private rooms receive the most reviews per month, indicating higher guest engagement.
#
# * Entire homes/apartments have fewer reviews, likely due to less frequent bookings or longer stays.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Airbnb can:
#
# * Promote private rooms for short-term, frequent bookings.
#
# * Encourage hosts of entire homes to improve listing appeal or offer shorter stays.
#
# Negative insight:
#
# * Low review rates for some room types may reflect reduced visibility or pricing mismatches, which can impact revenue.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
#Average Number of Nights

group_names = neighbourhoods_per_group.index.tolist()
pie_colors = sns.color_palette("Set2", len(group_names))
color_map = dict(zip(group_names, pie_colors))

bar_colors = [color_map[group] for group in avg_min_nights.index]

plt.figure(figsize=(12, 6))
avg_min_nights.plot(
    kind='bar',
    color=bar_colors,
    edgecolor='black'
)

plt.title("Average Number of Nights by Neighbourhood Group", fontsize=16, fontweight='bold')
plt.xlabel("Neighbourhood Group", fontsize=12)
plt.ylabel("Average Nights", fontsize=12)
plt.xticks(rotation=0, fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is ideal for comparing average minimum night requirements across neighbourhood groups clearly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Manhattan has the highest average minimum nights, suggesting listings target longer stays.
#
# * Bronx and Staten Island have the lowest, suitable for short-term travelers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Airbnb can:
#
# * Help hosts adjust minimum night policies based on guest demand.
#
# * Target marketing for short stays in low-barrier areas and long stays in premium areas.
#
# Negative insights:
#
# * High minimum stay requirements in certain areas might reduce booking frequency, limiting host earnings.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
#Relationship between Minimum Nights and Price

scatter_color = sns.color_palette("pastel")[2]  # light purple/pink tone

plt.figure(figsize=(10, 6))
plt.scatter(
    filtered_data['minimum_nights'],
    filtered_data['price'],
    alpha=0.5,
    color=scatter_color,
    edgecolor='black',
    linewidth=0.3,
    s=40
)

plt.title("Relationship between Minimum Nights and Price", fontsize=16, fontweight='bold')
plt.xlabel("Minimum Nights Required", fontsize=12)
plt.ylabel("Price (USD)", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.4)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot effectively visualizes the spread and pattern between minimum nights and prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * No strong correlation exists between minimum nights and price.
#
# * Most listings require 1–7 nights, with prices varying significantly within that range.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Hosts can:
#
# * Adjust minimum night policies without fearing price drop.
#
# * Focus on optimizing price based on market, not just duration.
#
# Negative insights:
#
# * Listings with very high minimum nights and low bookings may indicate inefficient strategy, reducing host earnings.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Plotting the heatmap

plt.figure(figsize=(12, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, fmt='.2f')

plt.title('Correlation Heatmap of Numerical Features', fontsize=16, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(rotation=0, fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap is ideal to show correlation strength between numeric variables, making it easier to spot potential relationships.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Most variables (like price, availability, minimum_nights, etc.) have low to moderate correlation.
#
# * A slight negative correlation may exist between price and reviews_per_month, suggesting higher-priced listings get fewer reviews.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

plt.figure(figsize=(12, 6))
sns.pairplot(pairplot_data, diag_kind='kde', plot_kws={'alpha': 0.5, 's': 20})
plt.suptitle("Pair Plot of Key Numerical Variables", y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is ideal for exploring relationships between multiple numerical features at once. It also highlights the distribution of each variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * No clear linear trends observed.
#
# * Price and minimum nights show a few extreme outliers.
#
# * Most variables show scattered relationships, suggesting complexity in data.

# %% [markdown]
# #### Chart - 16 - Map Visualization

# %%
#Map Visualization with Plotly

fig = px.scatter_mapbox(
    sample_df2,
    lat='latitude',
    lon='longitude',
    color='neighbourhood_group',
    size='price',
    hover_name='name',
    mapbox_style="carto-positron",
    title='Airbnb Listings in NYC (Sample)',
    height=1000,
    zoom=10
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter map is perfect for geographic data. It visually represents listings across NYC using location (lat/lon), price, and neighbourhood group, making spatial patterns easy to identify.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Manhattan has the highest density of listings with larger price markers.
#
# * Brooklyn also shows a high number of listings, but generally with smaller sizes (lower prices).
#
# * Outlying boroughs like Staten Island and Bronx have fewer listings and are more scattered.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. It:
#
# * Helps in location-based marketing strategies.
#
# * Identifies high-demand zones for pricing and investment.
#
# * Aids decision-making on where to expand or optimize listings.
#
# Negative insights:
#
# * Over-saturation in Manhattan could indicate high competition.
#
# * Listings far from central areas may suffer from low visibility and demand.

# %% [markdown]
# #### Chart - 17

# %%
# Chart - 17 visualization code
#Box Plot of Price by Room Type

plt.figure(figsize=(10, 6))
sns.boxplot(x='room_type', y='price', data=filtered_data3, palette='Set3')
plt.title('Box Plot of Price by Room Type')
plt.ylabel('Price ($)')
plt.xlabel('Room Type')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot is ideal for showing the spread and distribution of prices, identifying medians, interquartile ranges, and outliers for each room type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Entire home/apt has the highest median price and largest spread.
#
# * Private rooms are more affordable with lower variation.
#
# * Shared rooms are priced the lowest, often clustered under $100.
#
# * There are notable outliers, especially in "Entire home/apt", suggesting luxury or premium listings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes:
#
# * Helps set optimal pricing per room type.
#
# * Assists hosts in benchmarking their listing’s price.
#
# * Guides new investors on affordability vs. profitability tradeoffs.
#
# Insights that lead to negative growth are:
#
# * Extreme outliers in price may discourage bookings if not justified by listing quality.
#
# * Too many low-priced shared rooms could signal lower profit margins in that category.

# %% [markdown]
# #### Chart - 18

# %%
# Chart - 18 visualization code
#Average Price by Number of Reviews (used as a proxy for popularity)

line_color = sns.color_palette("pastel")[2]  # light green

plt.figure(figsize=(10, 6))
plt.plot(
    avg_price_by_reviews['number_of_reviews'],
    avg_price_by_reviews['price'],
    color=line_color,
    linewidth=2,
    marker='o',
    markersize=4,
    markerfacecolor='white',
    markeredgecolor='black'
)

plt.title('Average Price vs. Number of Reviews', fontsize=16, fontweight='bold')
plt.xlabel('Number of Reviews', fontsize=12)
plt.ylabel('Average Price (USD)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.4)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart was selected to show how the average price trends as the number of reviews (used as a proxy for listing popularity) increases. It helps reveal trends over a continuous variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Listings with fewer reviews tend to have higher average prices, possibly indicating new or premium properties.
#
# * As the number of reviews increases, the average price generally decreases, suggesting that popular listings are more affordable or that lower-priced listings attract more frequent bookings and reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes:
#
# * Helps hosts understand that lower pricing may boost popularity and booking frequency.
#
# * Assists platforms and marketers in targeting pricing strategies based on review volume.
#
# * Can help new hosts choose optimal starting prices to gather initial reviews quickly.
#
# Insights that lead to negative growth are:
#
# * Premium or high-priced listings might struggle to gain frequent reviews unless they improve value perception.
#
# * Over-discounting to increase review count could hurt revenue margins if not balanced carefully.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1. Target High-Performing Areas
#
#   Focus on boroughs like Manhattan and Brooklyn, which consistently show:
#
# * High listing density
# * Strong guest engagement
# * Higher average and median prices
#
#   This suggests strong market demand, making them ideal for expanding listings or investing in premium offerings like entire homes or apartments.
#
#
# 2. Optimize Room Type Strategy
#
#   The analysis shows:
#
# * Entire home/apt listings command the highest prices
# * Private rooms are more popular in outer boroughs like Queens and Bronx
#
#   👉 Hosts can diversify their listings or optimize offerings based on borough-specific demand to maximize revenue.
#
# 3. Set Competitive Prices Using Data
#
#   Use insights from:
#
# * Average and median price comparisons
# * Price vs. reviews/engagement trends
# * Room type and location-based pricing patterns
#
#   This will help hosts set smart, competitive prices that reflect demand and guest expectations.
#
# 4. Minimize Minimum Nights (When Possible)
#
#   Listings with a minimum stay between 1–7 nights had the widest appeal and highest review frequency. Reducing minimum night requirements can:
#
# * Attract short-term travelers
# * Improve booking frequency
# * Boost reviews and visibility

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This project provided a comprehensive analysis of the Airbnb NYC 2019 dataset to understand the dynamics of short-term rental listings across New York City. By exploring key features such as location, room types, pricing, guest engagement, and availability, we were able to extract valuable insights that highlight both current market trends and areas for strategic improvement.
#
# The analysis revealed that Manhattan and Brooklyn dominate the Airbnb landscape, both in terms of listing volume and pricing power. Entire homes/apartments consistently generate higher prices, particularly in central boroughs. In contrast, private rooms are more common in budget-friendly areas like Queens and the Bronx. Scatter plots showed that while there’s no strong linear correlation between price and factors like reviews or minimum nights, listings with 1–7 night minimum stays tend to be more competitive and attractive to guests.
#
# Visualizations such as pie charts, box plots, heatmaps, and scatter plots allowed us to understand not only the structure of the dataset but also patterns in host behavior, guest preferences, and listing performance. Furthermore, geo-based plots helped us see how listings are distributed across the city, offering clues about potential market saturation and untapped opportunities.
#
# In summary, the data supports that a data-driven approach to pricing, listing strategy, and geographic targeting can significantly enhance host performance and guest satisfaction. These findings can help Airbnb and its hosts make more informed decisions, leading to higher occupancy rates, better customer experiences, and improved profitability.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
